# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **YouTube's Trending Videos**

# %% [markdown]
# The original data from [Kaggle](https://www.kaggle.com/datasets/pyuser11/youtube-trending-videos-updated-daily/data) features video data across several major categories like movies, music, and gaming featured on select YouTube Trending pages. For the sake of this analysis, I chose to focus on the trending videos from the main homepage (the `default` datasets), allowing for the whole gamut of chaos that one can find on YouTube and to better understand what _'trending on Youtube'_ looks like over the course of March 2025. The data provided is seperated by date, so one of the first things to do will involve joining all the seperate datasets together for our use.

# %% [markdown]
# ## **Loading the Data**

# %%
o= pd.read_csv('~/Desktop/data/default_20250301.csv')
t=pd.read_csv('~/Desktop/data/default_20250302.csv')
tr=pd.read_csv('~/Desktop/data/default_20250303.csv')
f=pd.read_csv('~/Desktop/data/default_20250304.csv')
fi=pd.read_csv('~/Desktop/data/default_20250305.csv')
s=pd.read_csv('~/Desktop/data/default_20250306.csv')
se=pd.read_csv('~/Desktop/data/default_20250307.csv')
ei=pd.read_csv('~/Desktop/data/default_20250308.csv')
n=pd.read_csv('~/Desktop/data/default_20250309.csv')
ten=pd.read_csv('~/Desktop/data/default_20250310.csv')
el=pd.read_csv('~/Desktop/data/default_20250311.csv')
tw=pd.read_csv('~/Desktop/data/default_20250312.csv')
tt=pd.read_csv('~/Desktop/data/default_20250313.csv')
ft=pd.read_csv('~/Desktop/data/default_20250314.csv')
fit=pd.read_csv('~/Desktop/data/default_20250315.csv')
six=pd.read_csv('~/Desktop/data/default_20250316.csv')
svt=pd.read_csv('~/Desktop/data/default_20250317.csv')
eit=pd.read_csv('~/Desktop/data/default_20250318.csv')
nit=pd.read_csv('~/Desktop/data/default_20250319.csv')
twe=pd.read_csv('~/Desktop/data/default_20250320.csv')
ton=pd.read_csv('~/Desktop/data/default_20250321.csv')
twt=pd.read_csv('~/Desktop/data/default_20250322.csv')
twtr=pd.read_csv('~/Desktop/data/default_20250323.csv')
twf=pd.read_csv('~/Desktop/data/default_20250324.csv')
twfi=pd.read_csv('~/Desktop/data/default_20250325.csv')
twsi=pd.read_csv('~/Desktop/data/default_20250326.csv')
twse=pd.read_csv('~/Desktop/data/default_20250327.csv')
twei=pd.read_csv('~/Desktop/data/default_20250328.csv')
twni=pd.read_csv('~/Desktop/data/default_20250329.csv')
thir=pd.read_csv('~/Desktop/data/default_20250330.csv')
thiro=pd.read_csv('~/Desktop/data/default_20250331.csv')

thir.head()
# Out:
#                                                title  \
# 0                        REACTING TO FAN EDITS AGAIN
# 1                      My Biggest Hyperfixation Yet.
# 2        Squid Game In Real Life: Beta Squad Edition
# 3      I HOSTED AAU BASKETBALL TRYOUTS IN BALTIMORE!
# 4  Duke vs. Alabama - Elite Eight NCAA tournament...
#
#                                          description      videoId  \
# 0  God Bless the Quenaissance \n\nUse my code for...  uOMyMt1cz80
# 1  this tiny thing is consuming my entire life......  vp_dzqZXgMg
# 2  We take on Squid Game In Real Life! Last Perso...  52iBKzh3oWU
# 3  OUR FIRST TOURNAMENT IS THIS WEEKEND! YALL KNO...  Ij1-7dMoC18
# 4  Watch the highlights from No. 1 Duke and No. 2...  MuS_YNeYoQ0
#
#                                           thumbnails        channelName  \
# 0  [{'quality': 'maxres', 'url': 'https://i.ytimg...  Quenlin Blackwell
# 1  [{'quality': 'maxres', 'url': 'https://i.ytimg...   JaidenAnimations
# 2  [{'quality': 'maxres', 'url': 'https://i.ytimg...         Beta Squad
# 3  [{'quality': 'maxres', 'url': 'https://i.ytimg...         Cam Wilder
# 4  [{'quality': 'maxres', 'url': 'https://i.ytimg...      March Madness
#
#                   channelId                                 channelUrl  \
# 0  UCRE2zmVNW9wG2dndMoV4JKQ     https://www.youtube.com/@QUENBLACKWELL
# 1  UCGwu0nbY2wSkW8N-cghnLpA  https://www.youtube.com/@jaidenanimations
# 2  UCxOzbkk0bdVl6-tH1Fcajfg         https://www.youtube.com/@BetaSquad
# 3  UCkNB_lQah9MLniBLlk97iBw         https://www.youtube.com/@CamWilder
# 4  UCKjEtnnXEHsXE9IvCb92V7g      https://www.youtube.com/@MarchMadness
#
#    verified publishedText             publishedDate        viewsText    views  \
# 0      True  22 hours ago  2025-03-29T22:00:08.341Z    675,348 views   675348
# 1      True     1 day ago  2025-03-29T20:00:08.341Z  2,384,589 views  2384589
# 2      True     1 day ago  2025-03-29T20:00:08.341Z  3,185,712 views  3185712
# 3      True     1 day ago  2025-03-29T20:00:08.341Z    481,794 views   481794
# 4     False  16 hours ago  2025-03-30T04:00:08.341Z    746,956 views   746956
#
#                                       videoUrl  duration durationText  isShort
# 0  https://www.youtube.com/watch?v=uOMyMt1cz80      1956        32:36    False
# 1  https://www.youtube.com/watch?v=vp_dzqZXgMg       797        13:17    False
# 2  https://www.youtube.com/watch?v=52iBKzh3oWU      3821      1:03:41    False
# 3  https://www.youtube.com/watch?v=Ij1-7dMoC18      2373        39:33    False
# 4  https://www.youtube.com/watch?v=MuS_YNeYoQ0       623        10:23    False

# %% [markdown]
# ### Based on the data explanation (also provided via kaggle), we have the following columns:
#
# |Column Name | Description|
# |-|-|
# |`title`| The title of the video.|
# |`description`| The video's description|
# |`publishedDate`| The date and time when the video was published (in a machine-readable format)|
# |`publishedText`| The date and time when the video was published (in a human-readable format)|
# |`videoId`| The unique identifier for the video|
# |`videoUrl`| The URL of the video|
# |`channelName`| The name of the channel that published the video.|
# |`channelId`| The unique identifier for the channel.|
# |`channelUrl`| The URL of the channel.|
# |`thumbnails`| URLs for the video's thumbnail images in different resolutions.|
# |`views`| The number of views the video has received.|
# |`viewsText`| The number of views in a human-readable format (e.g., "1.2M views").|
# |`duration`| The duration of the video (in a machine-readable format).|
# |`durationText`| The duration of the video in a human-readable format (e.g., "3:24").|
# |`verified`| A boolean indicating whether the channel is verified or not.|
# |`isShort`| A boolean indicating whether the video is a YouTube Shorts video or not.|

# %% [markdown]
# ## **Cleaning & Joining Data:**
# Before concatenating the individual datasets together, I am going to add date columns so we can keep track of when certain videos were on the homepage. While there is a `publishedDate` column in the data, it does not remain consistent among all entries for a video so we will choose to ignore it.

# %%
o['Date']='2025-03-01'
t['Date']='2025-03-02'
tr['Date']='2025-03-03'
f['Date']='2025-03-04'
fi['Date']='2025-03-05'
s['Date']='2025-03-06'
se['Date']='2025-03-07'
ei['Date']='2025-03-08'
n['Date']='2025-03-09'
ten['Date']='2025-03-10'
el['Date']='2025-03-11'
tw['Date']='2025-03-12'
tt['Date']='2025-03-13'
ft['Date']='2025-03-14'
fit['Date']='2025-03-15'
six['Date']='2025-03-16'
svt['Date']='2025-03-17'
eit['Date']='2025-03-18'
nit['Date']='2025-03-19'
twe['Date']='2025-03-20'
ton['Date']='2025-03-21'
twt['Date']='2025-03-22'
twtr['Date']='2025-03-23'
twf['Date']='2025-03-24'
twfi['Date']='2025-03-25'
twsi['Date']='2025-03-26'
twse['Date']='2025-03-27'
twei['Date']='2025-03-28'
twni['Date']='2025-03-29'
thir['Date']='2025-03-30'
thiro['Date']='2025-03-31'

# %%
df=pd.concat([o,t,tr,f,fi,s,se,ei,n,ten,el,tw,tt,ft,fit,six,svt,eit,nit,twe,ton,twt,twtr,twf,twfi,twsi,twse,twei,twni,thir,thiro]).reset_index(drop=True)
df['Date']=pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          3120 non-null   object
#  1   description    3016 non-null   object
#  2   videoId        3120 non-null   object
#  3   thumbnails     3120 non-null   object
#  4   channelName    3120 non-null   object
#  5   channelId      3120 non-null   object
#  6   channelUrl     3120 non-null   object
#  7   verified       3120 non-null   bool
#  8   publishedText  3120 non-null   object
#  9   publishedDate  3120 non-null   object
#  10  viewsText      3032 non-null   object
#  11  views          3120 non-null   int64
#  12  videoUrl       3120 non-null   object
#  13  duration       3120 non-null   int64
#  14  durationText   3120 non-null   object
#  15  isShort        3120 non-null   bool
#  16  Date           3120 non-null   datetime64[ns]
# dtypes: bool(2), datetime64[ns](1), int64(2), object(12)
# memory usage: 371.8+ KB

# %% [markdown]
# As we can see from the above, there are some columns that contain nulls (i.e. `description` and `viewsText`). We could fill or get rid of any nulls, but, those columns will not be of use for our focus, so we will disregard them for now.

# %% [markdown]
# ## **What does it mean to trend?** The Who & What and Are they being influenced by Viewer Engagement?
#
# While there are many questions to have about the who, what, where, how, and why of the videos being featured on the YouTube homepage, given the data we have available, I am choosing to focus on the Who & What is being featured on the homepage to determine what YouTube means when they say 'trending' and whether this is affected by viewer engagement. More specifically, I will address the following:
#
# **1. Who's videos are being featured on the homepage in March 2025?**
# - What portion of videos featured on the homepage come from verified creators?
# - Who, of those featured on the homepage, is verified and not verified? Is there a pattern?
# - Who are the most featured creators during this period?
#
# **2. What is being featured on the homepage and why is it there?**
# - Does each day have different trending videos?
# - What videos frequented the homepage the most?
# - What criteria gets a video on the homepage?
#     - Is it the views?
#     - What about the views of when a video is first featured on the homepage?
# - What criteria keeps a video on the homepage? What dictates that a video's tenure must end?

# %% [markdown]
# ### <ins> 1. Who's videos are being featured on the homepage?:</ins>
# #### <span style="color: blue;">_What portion of videos featured on the homepage come from verified creators?_</span>
#
# One of the biggest advantages of YouTube in today's media landscape, is how, in comparison to traditional media distributors like Warner Brothers Discovery & NBC Universal, YouTube does not have to take on the role of content creator and invest in 'unproven' content. It relies on independent creators to create content to be streamed on the platform. It is only when said content / creator proves to be popular that YouTube starts to invest and approve monetization of specified content. In this way, YouTube stays ahead of traditional media corporations that often stick to continuations of known commercial successes (to reduce risk in a weak ad market and continue to be 'competitive' in this age of streaming) and has risen to [become the most viewed among all media distributors](https://www.nielsen.com/news-center/2025/youtube-achieves-best-monthly-performance-to-date-and-pulls-ahead-in-nielsens-february-media-distributor-gauge/)

# %%
v= df['verified'].value_counts()
plt.pie(v, labels=v.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Verified Creator Videos on YouTube homepage in March 2025')
plt.show()

# %% [markdown]
# As a majority of the videos come from verified users (verification, being a key step in being able to monetize content via YouTube's Partnership Program), this could be the result of YouTube picking their YPP participants well or it could be the result of YouTube setting a specific ratio for verified/unverified creators being featured on the homepage.
#
# When zooming in to look at specific days, like March 14, 2025 below, the ratio is pretty close to a 70/30 split between verified and unverified channels being featured on the homepage. This further supports that there may be a set ratio for what kind of creators get featured, favoring verified creators.

# %%
u= df.loc[df['Date']=='2025-03-14']['verified'].value_counts()
plt.pie(u, labels=u.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Verified Creator Videos on YouTube homepage on 3/14/25')
plt.show()

# %% [markdown]
# #### <span style="color: blue;">_Who, of those featured on the homepage in March 2025, is verified and not verified? Is there a pattern?_</span>
#
# As we looked at the fraction of verified/ unverified creators are featured on the homepage, we must also ask what kinds of creators make up these groups.

# %%
list(df.loc[df["verified"] == True]['channelName'].unique())
# Out:
# ['C-SPAN',
#  'Universal Pictures',
#  'Drew Gooden',
#  'JaidenAnimations',
#  'Jesser',
#  "Louie's Life",
#  'Jake Webber',
#  'Warner Bros.',
#  'LLOUD Official',
#  'Royal Court',
#  'The Official Pokémon YouTube channel',
#  'Clash of Clans',
#  'FRANCE 24 English',
#  'Hay Day',
#  'NPR Music',
#  'Mythri Movie Makers',
#  'Inside Edition',
#  'Firelight',
#  'Xiaomanyc 小马在纽约',
#  'This Esme',
#  'colinfurze',
#  'Grian',
#  'Schaffrillas Productions',
#  'Austin John Plays',
#  'NRL - National Rugby League',
#  'Will Tennyson',
#  'Eli Mack',
#  'Daniel Krafft',
#  'Marques Brownlee',
#  'DazzReviews',
#  'NFL',
#  'ESPN FC',
#  'Star Wars',
#  'Brawl Stars',
#  'Dude Perfect',
#  '60 Minutes',
#  'Quenlin Blackwell',
#  'Airrack',
#  'Sam and Colby',
#  'CBS Sports Golazo',
#  'House Committee on the Judiciary',
#  'Cutie The Bunny',
#  'Kurzgesagt – In a Nutshell',
#  'MrBeast',
#  'Evbo',
#  'Drew Dirksen',
#  'videogamedunkey',
#  'TD BRICKS',
#  'Alexa Rivera',
#  'elliot',
#  'Premier Boxing Champions',
#  'WWE',
#  'Sports On Prime',
#  'Fight Hub TV',
#  'Ice Cream Sandwich',
#  "Britain's Got Talent",
#  'Alan Becker',
#  'Nick Pro',
#  'JxmyHighroller',
#  'Family Island Game',
#  'Aniplex USA',
#  'LALIGA EA SPORTS',
#  'Alfie Deyes Vlogs',
#  'Oscars',
#  'ABC',
#  'ABC News',
#  'The Royalty Family',
#  'Channel 4 News',
#  "Let's Game It Out",
#  'CBS Miami',
#  'Major League Soccer',
#  'Qui & Ken Vlogs',
#  'mrnigelng',
#  'Doctor Who',
#  'VALORANT',
#  'al1',
#  'Zoe Sugg',
#  'The United Stand',
#  'pierson',
#  'Danny Gonzalez',
#  'Stuff Made Here',
#  'special edd',
#  'OSSA',
#  'David Alvareeezy',
#  'SLV Cinemas',
#  'LastWeekTonight',
#  'LazarBeam',
#  '5IVE GUYS FC',
#  'Jordan Matter',
#  'The White House',
#  '6abc Philadelphia',
#  'WIRED',
#  'GQ',
#  'TUDN USA',
#  'The Film Theorists',
#  'Ryland vlogs',
#  'FOBBV CAM',
#  'Veritasium',
#  'MiniminterClips',
#  'Bryson DeChambeau',
#  'Kai Cenat Live',
#  'Korporate Bidness',
#  'The Deal Guy',
#  'TODAY with Jenna & Friends',
#  'IShowSpeed',
#  'Phil Mickelson and the HyFlyers',
#  'Minecraft',
#  'fern',
#  'MoreSidemen',
#  'GnB Official ',
#  'HYBE LABELS',
#  'First We Feast',
#  'CouRage Gaming',
#  'CrossFit Games',
#  'NBA on TNT',
#  'Hoop Reports',
#  'Radio Javan',
#  'American Idol',
#  'Spotify',
#  'Millennial Farmer',
#  'Rancho Humilde',
#  'Santea',
#  'Max Fosh',
#  'ChrisMD',
#  'Primitive Technology',
#  'ABC 33/40',
#  'Outdoor Boys',
#  'ESPN',
#  'Marvel Entertainment',
#  'AXS TV',
#  'brewstewfilms',
#  'KOIN 6',
#  'Mia Maples',
#  'How Ridiculous',
#  'WWE on USA',
#  'Maizen',
#  'Amelia Dimoldenberg',
#  'Breakfast Club Power 105.1 FM',
#  'Moriah Elizabeth',
#  'James Charles',
#  'Throttle House',
#  'Futcrunch',
#  'Cash',
#  'Sidemen',
#  'Charles & Alyssa Forever',
#  'Max',
#  'AMP',
#  'Royalty Gaming',
#  'Karl',
#  'Live Speedy',
#  'Kara and Nate',
#  'MrBeast 2',
#  'Stay Wild',
#  'ESPN MMA',
#  'W Magazine',
#  'Foltyn',
#  'PrestonPlayz',
#  'Awakening Music',
#  'JYP Entertainment',
#  'Mat Armstrong',
#  'Wifies',
#  'SMTOWN',
#  'emma chamberlain',
#  'ADAM RAY OKAY',
#  'Suits Official',
#  'Yeah Jaron',
#  'The Colin Cowherd Podcast',
#  'Cam Wilder',
#  'BamaBass',
#  'Eurovision Song Contest',
#  'Sky Sports Cricket',
#  'Eamon & Bec',
#  'Max & Occy',
#  'Mrwhosetheboss',
#  'LIL JERZ',
#  'FOX 35 Orlando',
#  'JerryRigEverything',
#  'The Skip Bayless Show',
#  'Call of Duty',
#  'Lauren & Arie',
#  'PlayOverwatch',
#  'The Overlap',
#  'FOX6 News Milwaukee',
#  'Netflix',
#  'The AFC Hub',
#  'Ghost Town Living',
#  'TBJZL',
#  'CookieRun: Kingdom',
#  'Theo Baker',
#  'The Fellas',
#  "Gil's Arena",
#  'Jatie Vlogs',
#  'not Otzdarva',
#  'WPBF 25 News',
#  'PIX11 News',
#  'The Food Theorists',
#  'Tarayummy',
#  'East Idaho News',
#  'SmallAnt',
#  'Path of Exile',
#  'Dylan Is In Trouble',
#  'SpookyLoopz',
#  'Fore Play Golf',
#  'Around The Association',
#  'Disney',
#  'KAED',
#  'PGA TOUR',
#  'Concacaf',
#  'First Coast News',
#  'Golf Channel',
#  "D'Vontay Friga",
#  'State Farm Insurance',
#  'XtremeGamez',
#  'FOX SPORTS AUSTRALIA',
#  'James May’s Planet Gin',
#  'Phoenix SC',
#  'Chris Dixon',
#  'Logan Paul',
#  'h4kpy',
#  '7PM in Brooklyn with Carmelo Anthony',
#  'Jynxzi',
#  'FORMULA 1',
#  'PlayStation',
#  'Ubisoft',
#  'Dominique Sachse',
#  'Heavy Spoilers',
#  'BWF TV',
#  'JJ Olatunji',
#  'Calfreezy',
#  'Stephen & Samantha',
#  'Kalogeras Sisters ',
#  'VideoFromSpace',
#  'Junkyard Digs',
#  'YourFriendKyle',
#  'Ali-A²',
#  'Idols Global',
#  'Mighty Goat',
#  'KBS WORLD TV',
#  'Mark Rober',
#  'Ryan Trahan',
#  'CNET',
#  'Safiya Nygaard',
#  'CrunchLabs',
#  'The Game Theorists',
#  'WJTV 12 News',
#  'BrentTV',
#  'AnimationEpic',
#  'Manx Ninja Pig',
#  'The Spiffing Brit',
#  'Wild Iron',
#  'NZC',
#  'Living Big In A Tiny House',
#  'ESPN Deportes',
#  'SMii7Yplus',
#  'MindofRez',
#  'Joshua Weissman',
#  'Project Farm',
#  'WTA',
#  'morgans vlogs',
#  'Newcastle United',
#  'Wanted ⭐',
#  'TommyInnit',
#  'Sky Sports Football',
#  'theneedledrop',
#  'Duke Dennis',
#  'Clix',
#  'itsjusta6',
#  'NASA',
#  'brian david gilbert',
#  'AiTelly',
#  'The Baseball Bat Bros',
#  'Morley',
#  "Celaine's ASMR",
#  'Depressed Ginger',
#  'Chris Harris on Cars',
#  'THE RACE',
#  'MLB',
#  'ACG',
#  'A24',
#  'NBC4 Washington',
#  'FOX',
#  'B N S',
#  'RDCworld1',
#  'gameranx',
#  '7NEWS Australia',
#  'Apple',
#  'Any Austin',
#  'FOX 5 New York',
#  'bald and bankrupt',
#  'Niko Omilana',
#  'Cj Dachamp',
#  'Brooklyn and Bailey',
#  'Lionsgate Movies',
#  'Boston Dynamics',
#  'Westen Champlin',
#  'Aashirvad Cinemas',
#  'Jeremy Jahns',
#  'Computer Clan',
#  'Magnus Midtbø',
#  'Sherri',
#  'Hulu',
#  'GeoBeats Animals',
#  'CaylusBlox',
#  'Markiplier',
#  'Doug DeMuro',
#  'martincitopantsLIVE',
#  'League of Legends',
#  'CBS Sports Golazo America',
#  'CONMEBOL',
#  'FOX Soccer',
#  'The Tonight Show Starring Jimmy Fallon',
#  'Brittany Broski Music',
#  'Selección Nacional de México',
#  'NBA on ESPN',
#  'Degenerocity',
#  'Wendover Productions',
#  'Skill Up',
#  'optimum',
#  'Miniminter',
#  'Jet Lag: The Game',
#  'CBS Evening News',
#  'LDShadowLady',
#  'FaZe Rug',
#  'GLITCH',
#  'Crunchyroll',
#  'Sky Sports F1',
#  'Hangtime',
#  'FrenchieFries',
#  'Wemmbu',
#  'UltraHands',
#  'Dungeon Soup',
#  'Nerdforge',
#  'Half-Asleep Chris',
#  'Chelsea Football Club',
#  'Les Do Makeup',
#  'PilotPhotog',
#  'Dream',
#  'Tana Mongeau',
#  'ABC 7 Chicago',
#  'Jesse James West',
#  'Gone with the Wynns',
#  'Trek Trendy',
#  'Naomi Jon',
#  'Ludwig',
#  'Bachelor Nation',
#  'WCVB Channel 5 Boston',
#  'Fortnite',
#  'zanny',
#  'The Deegans',
#  'Dropout',
#  'Midlife Stockman',
#  'Complex',
#  'German Football',
#  'Wide World of Sports',
#  'Simon Wilson',
#  'Telemundo Deportes',
#  'Monster Hunter',
#  'Beta Squad',
#  'WTOL11',
#  'Rick Beato',
#  'The Howard Stern Show',
#  'AFC Asian Cup',
#  'CNC Kitchen',
#  'Saberspark',
#  'People',
#  'Match Masters',
#  'Driver61',
#  'The Pat McAfee Show',
#  'SurvivorOnCBS',
#  'Stephen A. Smith',
#  'New Rockstars',
#  'Alix Earle',
#  'Rocky Kanaka',
#  'The Try Guys',
#  'tazoh',
#  'EA SPORTS F1',
#  'Mind the Game',
#  'Mark McCann',
#  'Nintendo of America',
#  'Nick Viall',
#  'NardwuarServiette',
#  'Burback',
#  'Josh Peck',
#  'Pitch Meeting',
#  'Johnnie Guilbert',
#  'Nightcap',
#  '2 Much ColinFurze',
#  'a bit more willne',
#  "Jojo's ASMR",
#  'Wicked Makers',
#  'mashed',
#  'Clash Royale',
#  'The Times and The Sunday Times',
#  'Chicago Bulls',
#  'WQAD News 8',
#  'NBC Sports',
#  'Sur Ronster',
#  'Real Madrid',
#  'Matthew Beem',
#  'Cocajola',
#  "Ryan Hall, Y'all",
#  'CoryxKenshin',
#  'Cut',
#  'Wunba',
#  'Famous Birthdays',
#  'MasterBuilders',
#  "Mandy's iPhone",
#  'Brady Shepherd',
#  'E! News',
#  'Crispy Concords',
#  'WJCL News',
#  'Tennis TV',
#  'Matt Slays',
#  'STUD',
#  'Not Enough Nelsons',
#  'Saturday Night Live',
#  'Parrot']

# %%
list(df.loc[df["verified"] == False]['channelName'].unique())
# Out:
# ['Fridayy',
#  'YoungBoy Never Broke Again',
#  'Future',
#  'Tito Double P',
#  'G Herbo',
#  'Lizzo Music',
#  'Jombriel',
#  '2 Danny 2 Furious',
#  'Benson Boone',
#  'SB19 Official',
#  'Malcolm Todd',
#  'ADÉLA',
#  'The Beeston Bunch',
#  'The Beeston Fam',
#  'Karan Aujla',
#  'Ze Frank',
#  'Mat Armstrong MK2',
#  'J. Cole',
#  'JENNIE',
#  'Jorjiana ',
#  'OfficialGDRAGON',
#  'Riley Green',
#  'Alex Warren',
#  'H O T B O I I',
#  'Sabrina Carpenter',
#  'Dany Ome & Kevincito El 13 ',
#  'JADE',
#  'Mr. Bricks',
#  'BossMan Dlow',
#  'LARRAY',
#  'Hudson Westbrook',
#  'Skote Outdoors',
#  'Kipper',
#  'Reality Daydream',
#  'RØZ - Topic',
#  'Yailin La Mas Viral',
#  'LUCKI',
#  'Tyla',
#  'Ghost',
#  'Doechii',
#  'Cleetus2 McFarland',
#  'GELO',
#  "Tony Hawk's Pro Skater",
#  'Don Toliver',
#  'Brian Weissman',
#  'Itzmegab3',
#  'Jayco',
#  'kevingatesTV',
#  'Dolly Parton',
#  'CBS Sports Golazo - Europe',
#  'Beéle',
#  'Fredo Bang',
#  'Lady Gaga',
#  'Hanumankind',
#  'TEC',
#  'The Young and Restless',
#  "Dave's DRH Acrylic Creations",
#  'Benjy Chavez ',
#  'KOJIMA PRODUCTIONS',
#  'XG',
#  'NPOP',
#  'alex james fiber',
#  'Skrilla',
#  'Bad Bunny',
#  'CBS Sports Golazo - Asia',
#  'Jayco & Val',
#  'Mahna Ghafori',
#  'Bhad Bhabie',
#  'Sleep Token',
#  'HAIM',
#  'Tito Ortega.',
#  'TaylorMade Golf',
#  'Mayzee - Minecraft',
#  'The Sketch Real',
#  'Selena Gomez',
#  'Chappell Roan',
#  'The Fish Guys',
#  'Lil Nas X',
#  'Big Wedge Golf',
#  'George Clarkey',
#  'Lil Baby Official ',
#  'Peso Pluma',
#  'Playboi Carti',
#  'Official DeeBabyTV',
#  'Eslabon Armado',
#  'Lil Tecca',
#  'P1 with Matt & Tommy',
#  'Daniel Caesar',
#  'NCAA Championships',
#  'Shawna The Mom',
#  'Tick Creek Ranch',
#  'MollyMae',
#  'Star Wars Centralized',
#  'sydney rose',
#  'Jordan Fabrics',
#  'Trixie Mattel',
#  'BLESSD EL BENDITO 💙',
#  'WSMV 4 Nashville',
#  'Sarahs Day',
#  'mgk',
#  'SMii7Yplays',
#  'YUNGBLUD',
#  'WVUE FOX 8 New Orleans',
#  'STAYC',
#  'Frannie Jo Savvy Sweet',
#  'Ravyn Lenae',
#  'CAZZU Canal Oficial',
#  'March Madness',
#  'Conan Gray',
#  'Kodak Black',
#  'Jack Harlow',
#  'Christian Nodal',
#  'Morgan Wallen',
#  'OG EPIC (EpiCure)',
#  'Lil Durk',
#  'Stray Kids',
#  'Arcangel',
#  'Los Ángeles Azules',
#  'Leon Thomas',
#  'Anes Kim',
#  'Kanye West',
#  'Fanatiz',
#  'Shakira',
#  'MoneyBagg Yo',
#  'emily ha',
#  'Mat Watson Cars',
#  'arcsystemworks',
#  'Azrilich',
#  'RAR Garage',
#  'NowWhat?!PotteryWorks',
#  'Rockout Danny ',
#  'NBA G League',
#  'Mentour Now!',
#  'ABC4 Utah',
#  'NewsWatch 12',
#  'Quadeca',
#  'Baller League UK',
#  'Michelle Maciel',
#  'ella langley',
#  'Cody Johnson',
#  'Emilia',
#  'Miley Cyrus',
#  'Joel Haver',
#  'Nettspend',
#  'Creative Geekery',
#  'Cash Cobain',
#  'Fisch',
#  'Chris Lebron',
#  'Jacob Collier',
#  'SNK OFFICIAL',
#  'HelloGamesTube',
#  'PresLee Faith',
#  'Linkin Park',
#  'Ariana Grande',
#  'Warner Bros. Pictures International',
#  'jtsandman45',
#  'Anycia',
#  'Off The Ranch',
#  'Burna Boy',
#  'BigXthaPlug',
#  'Rylo Rodriguez',
#  'Saucy Santana',
#  'Avery Woods',
#  'ON TOP MELO',
#  'KALI UCHIS',
#  'Lydia the Bard',
#  'Jinger & Jeremy Vuolo',
#  'LSU Tigers on TigerBait',
#  'Unspeakable Studios',
#  'Andrew Camarata',
#  'Old School Millennial']

# %% [markdown]
# What surprises me the most about these lists is how many popular musical artists are not verified (i.e Lizzo Music, Benson Boone, JENNIE, Sabrina Carpenter). As YouTube is a major avenue for artists to gain exposure and reach out to new audiences (at no expense to the audience), it is a good opportunity to monetize said following.
#
# Otherwise, the list of verified channels includes corporate accounts (i.e CSPAN, Warner Bros., Saturday Night Live) and known content creators as expected.

# %% [markdown]
# #### <span style="color: blue;">_Who are the most featured creators in March 2025? Are they verified?_</span>
#
# In comparison to previous analysis, 80% of the top featured creators in March 2025 are not verified. This of course leaves the answer to whether verified users are favored in being posted to the homepage as inconclusive.

# %%
x= df[['videoId','channelName']].drop_duplicates()
xx=x['channelName'].value_counts().head(20).reset_index()
xx.columns = ['Channel','Number of Featured Videos']

fig = sns.barplot(x='Number of Featured Videos', y='Channel',data=xx,palette='rocket',hue='Channel')

fig.set_title('Top Creators by Number of Featured Videos in March 2025',fontsize=18, weight ='semibold')
fig.set_xlabel('Number of Featured Videos',fontsize=10, labelpad=20,weight='semibold')
fig.set_ylabel('Channel',fontsize=5, labelpad=30, weight='semibold')
# Out:
# Text(0, 0.5, 'Channel')

# %%
ll=df[['channelName','verified']].drop_duplicates()
xx.rename(columns={'Channel':'channelName'},inplace=True)
h=xx.merge(ll,on='channelName')
l=h['verified'].value_counts()

plt.pie(l, labels=l.index, autopct='%1.1f%%', startangle=90)
plt.title('Of the top 20 featured creators in 2025, how many are verified?')
plt.show()

# %% [markdown]
# ### <ins> 2. What is being featured on the homepage?
#
# #### <span style="color: blue;">_Does each day have different trending videos?_</span>
# While unlikely, given the autocorrelative nature of 'trending videos' over the course of a month (trending generally depends on engagement metrics like views and views today depend on the views yesterday as they compound), there is a possbility that YouTube may try to highlight different videos on its homepage each day.
#
# In the concatenated dataset, we have 3120 entries but we find that there are only 896 unique video IDs over the course of March, which tells us that a lot of the videos that appeared on the homepage in March 2025, appeared multiple times during the course of the month.

# %%
df['videoId'].nunique()
# Out:
# 896

# %% [markdown]
# #### <span style="color: blue;">_What videos frequented the homepage the most?_</span>
#
# Within the top 20 most frequently featured videos, we find that a majority (7/20) are music videos from recognizable artists like Doechii and Selena Gomez (that are not verified channels) and the remainder come from verified content creators.

# %%
trend_video = df['title'].value_counts().head(20).reset_index()
trend_video.columns = ['Video', 'count']


fig = sns.barplot(x='count', y='Video',data=trend_video,palette='rocket',hue='Video')

fig.set_title('Top Trending Videos by Number of Days on Homepage in March 2025',fontsize=18, weight ='semibold')
fig.set_xlabel('Days on Homepage',fontsize=10, labelpad=20,weight='semibold')
fig.set_ylabel('Video',fontsize=5, labelpad=30, weight='semibold')
# Out:
# Text(0, 0.5, 'Video')

# %%
#channels of videos in the Top 20 most featured videos in March 2025 ranking
df[df['title'].isin(trend_video['Video'])]['channelName'].unique()
# Out:
# array(['Drew Gooden', 'Tito Double P', 'Oscars', 'The Royalty Family',
#        'Danny Gonzalez', 'Yailin La Mas Viral', 'Doechii', 'JENNIE',
#        'First We Feast', 'Outdoor Boys', 'AMP', 'MoreSidemen',
#        'Bhad Bhabie', 'Disney', 'KAED', 'Selena Gomez',
#        'Lil Baby Official ', 'TD BRICKS', 'Mark Rober', 'SMii7Yplus'],
#       dtype=object)

# %%
#verification status of top 20 most featured
df.loc[df['title'].isin(trend_video['Video']),['channelName','verified']].drop_duplicates().reset_index(drop=True)
# Out:
#             channelName  verified
# 0           Drew Gooden      True
# 1         Tito Double P     False
# 2                Oscars      True
# 3    The Royalty Family      True
# 4        Danny Gonzalez      True
# 5   Yailin La Mas Viral     False
# 6               Doechii     False
# 7                JENNIE     False
# 8        First We Feast      True
# 9          Outdoor Boys      True
# 10                  AMP      True
# 11          MoreSidemen      True
# 12          Bhad Bhabie     False
# 13               Disney      True
# 14                 KAED      True
# 15         Selena Gomez     False
# 16   Lil Baby Official      False
# 17            TD BRICKS      True
# 18           Mark Rober      True
# 19           SMii7Yplus      True

# %% [markdown]
# However, when we look a little further to get an understanding of when the most frequently featured video may have been on the homepage, we find that on some days, some videos are being featured multiple times.
#
# For example, the _LEGO BUILDS for a DOG_ video (#1/20) appeared in the data twice on 2025-03-15 & 2025-03-16, 1-2 days since first being published / posted. To check whether this an error in the data or if it is possible that the video was featured on the homepage multiple times on the same date, we will check some of the other videos in the top 20 most featured list.

# %%
df.loc[df["title"] == "LEGO BUILDS for a DOG...",['Date','publishedText','views']].sort_values("Date")
#["title",'videoId', "views", "publishedDate", "Date"]
# Out:
#            Date publishedText     views
# 1418 2025-03-15     1 day ago    844154
# 1499 2025-03-15     1 day ago    844154
# 1532 2025-03-16    2 days ago   1089926
# 1586 2025-03-16    2 days ago   1089926
# 1682 2025-03-17    3 days ago   1291516
# 1787 2025-03-18    4 days ago   1513068
# 1888 2025-03-19    5 days ago   1735704
# 1990 2025-03-20    6 days ago   2176936
# 2073 2025-03-21    7 days ago   3463132
# 2168 2025-03-22    8 days ago   4914994
# 2266 2025-03-23    9 days ago   6399003
# 2366 2025-03-24   10 days ago   7479484
# 2473 2025-03-25   11 days ago   8458513
# 2572 2025-03-26   12 days ago   9430617
# 2681 2025-03-27   13 days ago  10292337
# 2787 2025-03-28   2 weeks ago  10966718
# 2893 2025-03-29   2 weeks ago  11532874
# 2999 2025-03-30   2 weeks ago  12035300
# 3110 2025-03-31   2 weeks ago  12461146

# %% [markdown]
# Doechii's _Anxiety (Visualizer)_ (#4/20) was also featured twice on the homepage on 3/6/25 & 3/7/25 1-2 days after posting.

# %%
df.loc[df["title"] == "Doechii - Anxiety (Visualizer)",['Date','publishedText','views']].sort_values("Date")
# Out:
#            Date publishedText     views
# 400  2025-03-05  19 hours ago    792669
# 506  2025-03-06     1 day ago   1812498
# 569  2025-03-06     1 day ago   1812498
# 632  2025-03-07    2 days ago   2880540
# 661  2025-03-07    2 days ago   2880540
# 768  2025-03-08    3 days ago   4146989
# 863  2025-03-09    4 days ago   5518143
# 956  2025-03-10    5 days ago   6877583
# 1058 2025-03-11    6 days ago   8187504
# 1155 2025-03-12    7 days ago   9462501
# 1262 2025-03-13    8 days ago  10637702
# 1363 2025-03-14    9 days ago  11763359
# 1469 2025-03-15   10 days ago  13181252
# 1571 2025-03-16   11 days ago  14575361
# 1672 2025-03-17   12 days ago  15801410
# 1783 2025-03-18   13 days ago  17040732
# 1891 2025-03-19   2 weeks ago  18318116

# %% [markdown]
# The data from Doechii's _Anxiety (Visualizer)_ and the _LEGO BUILDS for a DOG_ video suggest that there might be a pattern where a video can become double featured if published recently (1-2 days) and gain more than 500,000 views in that time. The data from Jennie's _like JENNIE_ music video (#17/20) does not seem to completely support this hypothesis, as the double postings occur within the 15 hours to 1 day since posting time frame but it also does not seem to refute that the views need to grow larger than 500,000 within the first 24-48 hours of being posted.

# %%
df.loc[df["title"] == "JENNIE - like JENNIE (Official Video)",['Date','publishedText','views']].sort_values("Date")
# Out:
#            Date publishedText     views
# 597  2025-03-07  15 hours ago   6610705
# 662  2025-03-07  15 hours ago   6610705
# 707  2025-03-08     1 day ago  11713923
# 760  2025-03-08     1 day ago  11713923
# 823  2025-03-09    2 days ago  15672156
# 947  2025-03-10    3 days ago  18930718
# 1056 2025-03-11    4 days ago  21618420
# 1153 2025-03-12    5 days ago  24145751
# 1260 2025-03-13    6 days ago  26437773
# 1359 2025-03-14    7 days ago  28804251
# 1466 2025-03-15    8 days ago  30999501
# 1568 2025-03-16    9 days ago  32998716
# 1670 2025-03-17   10 days ago  34792516
# 1781 2025-03-18   11 days ago  36479577
# 1890 2025-03-19   12 days ago  38130949

# %% [markdown]
# This will of course need to be investigated further in `What criteria gets a video on the homepage?`

# %% [markdown]
# #### <span style="color: blue;">_But what criteria gets a video on the homepage?_</span>
#
# Given the data we have available, I hypothesize that the view count is used to help determine placing on the homepage. As `views` is one of the few engagement metrics we have access to via this dataset and part of what we would normally expect to be used to define 'trending', this will be a good start to understand Youtube's logic to placing a video on the homepage.

# %% [markdown]
# **_Is it actually the views?_** Comparing the most viewed videos (of those featured on the March 2025 homepage) and the most featured videos
#
# I am going to start by taking a look at the max view count videos achieved while on the homepage. As the view counts are compounded daily, the maximum is generally the last day of a video's tenure on the homepage.

# %%
#find the max views of video
df_max_index = df.groupby('videoId')['views'].idxmax()
x= df.loc[df_max_index].sort_values(by='views',ascending=False).head(20).reset_index(drop=True)

x.head()
# Out:
#                                                title  \
# 0             I Spent 100 Hours Inside The Pyramids!
# 1  Kendrick Lamar's Apple Music Super Bowl Halfti...
# 2  100 People Trapped Inside 100 Circles For $500...
# 3         I Survived The 5 Deadliest Places On Earth
# 4              JENNIE - like JENNIE (Official Video)
#
#                                          description      videoId  \
# 0  I can’t believe we were allowed to do this\nSe...  NDsO1LT_0lw
# 1  Watch hip-hop’s MVP put on an epic performance...  KDorKy-13ak
# 2  Seeing these past contestants battle it out fo...  zajUgQLviwk
# 3  It’s crazy we actually did this\nOur new Feast...  aKq8bkY5eTU
# 4  Official music video for “like JENNIE” from th...  JSFG-IE8n_c
#
#                                           thumbnails channelName  \
# 0  [{'quality': 'maxres', 'url': 'https://i.ytimg...     MrBeast
# 1  [{'quality': 'maxres', 'url': 'https://i.ytimg...         NFL
# 2  [{'quality': 'maxres', 'url': 'https://i.ytimg...     MrBeast
# 3  [{'quality': 'maxres', 'url': 'https://i.ytimg...     MrBeast
# 4  [{'quality': 'maxres', 'url': 'https://i.ytimg...      JENNIE
#
#                   channelId  \
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA
# 1  UCDVYQ4Zhbm3S2dlz7P1GBDg
# 2  UCX6OQ3DkcsbYNE6H8uQQuVA
# 3  UCX6OQ3DkcsbYNE6H8uQQuVA
# 4  UCNYi_zGmR519r5gYdOKLTjQ
#
#                                           channelUrl  verified publishedText  \
# 0                   https://www.youtube.com/@MrBeast      True   3 weeks ago
# 1                       https://www.youtube.com/@NFL      True   3 weeks ago
# 2                   https://www.youtube.com/@MrBeast      True    3 days ago
# 3                   https://www.youtube.com/@MrBeast      True    2 days ago
# 4  https://www.youtube.com/channel/UCNYi_zGmR519r...     False   12 days ago
#
#               publishedDate          viewsText      views  \
# 0  2025-02-09T20:00:07.888Z  149,378,597 views  149378597
# 1  2025-02-13T20:00:07.297Z   97,236,538 views   97236538
# 2  2025-03-01T20:00:07.949Z   48,807,682 views   48807682
# 3  2025-03-22T20:00:07.242Z   43,335,403 views   43335403
# 4  2025-03-07T20:00:06.978Z   38,130,949 views   38130949
#
#                                       videoUrl  duration durationText  \
# 0  https://www.youtube.com/watch?v=NDsO1LT_0lw      1303        21:43
# 1  https://www.youtube.com/watch?v=KDorKy-13ak       801        13:21
# 2  https://www.youtube.com/watch?v=zajUgQLviwk      2318        38:38
# 3  https://www.youtube.com/watch?v=aKq8bkY5eTU       828        13:48
# 4  https://www.youtube.com/watch?v=JSFG-IE8n_c       183         3:03
#
#    isShort       Date
# 0    False 2025-03-02
# 1    False 2025-03-06
# 2    False 2025-03-04
# 3    False 2025-03-24
# 4    False 2025-03-19

# %%
fig = sns.barplot(x='views', y='title',data=x,palette='rocket',hue='title')

fig.set_title('Top Homepage Videos by View Count in March 2025',fontsize=18, weight ='semibold')
fig.set_xlabel('Max Views',fontsize=10, labelpad=20,weight='semibold')
fig.set_ylabel('Video',fontsize=5, labelpad=30, weight='semibold')

#there may be some warnings about inability to produce foreign characters, specifically Hangul
# Out:
# Text(0, 0.5, 'Video')
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from current font.
#   func(*args, **kwargs)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   func(*args, **kwargs)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   func(*args, **kwargs)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54604 (\N{HANGUL SYLLABLE PIM}) missing from current font.
#   func(*args, **kwargs)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47476 (\N{HANGUL SYLLABLE REU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/sayakapapas/Library/Python/3.8/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54604 (\N{HANGUL SYLLABLE PIM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# The top 20 most featured videos versus the top 20 most viewed among those featured in March 2025 share some commonalities (like, JENNIE - _like JENNIE_, Doechii - _Anxiety (Visualizer)_) but are pretty different on the whole. Doechii's _Anxiety (Visualizer)_ is ranked fourth in most featured video but is ranked 18th with 18,166,710 views in top 20 most viewed ranking.
#
# The most notable difference between the two rankings is how many more foreign language videos are included in the top 20 most viewed when compared to the top 20 most featured. As shown below (the **featured ranking** being the first 3 columns and the **viewing ranking** being the last 3 columns), we find that 7/20 in most viewed come from foreign creators and only 3/20 in the most featured ranking come from foreign creators.

# %%
s=trend_video.rename(columns={'Video':'title'})
#df_max_index = df.groupby('videoId')['views'].idxmax()
y=df.loc[df_max_index]
h=y[['title','views']].reset_index(drop=True)
p= s.merge(h,on='title').reset_index()
p.rename(columns={'title':'MOST FEATURED - title'},inplace=True)



viewed=x[['title','views']].reset_index()
f=df['title'].value_counts()
f.columns = ['title', 'count']
j=viewed.merge(f,on='title').reset_index(drop=True)
j.rename(columns={'title':'MOST VIEWED - title'},inplace=True)


p.merge(j, on='index').drop(['index'], axis=1)
# Out:
#                                 MOST FEATURED - title  count_x   views_x  \
# 0                            LEGO BUILDS for a DOG...       19  12461146
# 1              Tattoo - Tito Double P (Video Oficial)       19  20983434
# 2                             I'M HIGH SCHOOL MUSICAL       18   4796973
# 3                      Doechii - Anxiety (Visualizer)       17  18318116
# 4   Bhad Bhabie -  OG CRASHOUT (Official Music Video)       17   9314801
# 5   Ariana Grande and Cynthia Erivo 'Wicked' Perfo...       17   4291522
# 6   Forging a Knife & Survival Camping Alone in th...       17  10724886
# 7   Lilo & Stitch | Official Trailer | In Theaters...       17  11965512
# 8               There's Something LIVING in our Attic       17   8313046
# 9   Lil Baby, Young Thug, Future - Dum, Dumb, and ...       16   5953063
# 10                      My First Time Playing R.E.P.O       16   3996831
# 11              SIDEMEN AMONG US BUT EVERYTHING IS 3D       15   6388105
# 12          TIOS FOR A DAY W/ ADAM & LOUIE *FUNNY AF*       15   1211025
# 13                                 AMP MMA BASKETBALL       15   2994236
# 14  YAILIN LA MAS VIRAL x DJ ADONI - Yo No Olvido ...       15   5066208
# 15                   Can You Fool A Self Driving Car?       15  18674936
# 16              JENNIE - like JENNIE (Official Video)       15  38130949
# 17  Selena Gomez, benny blanco - Sunset Blvd (Offi...       15   7778781
# 18                       Technology isn't fun anymore       15   3975698
# 19  Bill Murray Doesn’t Flinch While Eating Spicy ...       14   4157288
#
#                                   MOST VIEWED - title    views_y  count_y
# 0              I Spent 100 Hours Inside The Pyramids!  149378597        2
# 1   Kendrick Lamar's Apple Music Super Bowl Halfti...   97236538        6
# 2   100 People Trapped Inside 100 Circles For $500...   48807682        3
# 3          I Survived The 5 Deadliest Places On Earth   43335403        4
# 4               JENNIE - like JENNIE (Official Video)   38130949       15
# 5                   Cazzu - CON OTRA (Official Video)   35110699       12
# 6   Good Bad Ugly Tamil Teaser | Ajith Kumar | Tri...   32276743        1
# 7                LE SSERAFIM (르세라핌) 'HOT' OFFICIAL MV   25711196        9
# 8    The Last of Us Season 2 | Official Trailer | Max   24809958       12
# 9     Final Destination Bloodlines | Official Trailer   23813631        7
# 10                               FAILED LEGO ITEMS...   23081650        1
# 11          JENNIE, Doechii - ExtraL (Official Video)   22715937        2
# 12                  A Minecraft Movie | Final Trailer   22303344       10
# 13             Tattoo - Tito Double P (Video Oficial)   20983434       19
# 14  G-DRAGON - TOO BAD (feat. Anderson .Paak) (Off...   18817591        1
# 15                   Can You Fool A Self Driving Car?   18674936       15
# 16       SIDEMEN CHARITY MATCH 2025 [OFFICIAL STREAM]   18466258       13
# 17                     Doechii - Anxiety (Visualizer)   18318116       17
# 18  The Paradise Glimpse : RAW STATEMENT - Telugu ...   18166710        1
# 19  LISA - FUTW (Vixi Solo Version) (Official Musi...   16681811        7

# %% [markdown]
# **_But what about the views of when a video may first be featured on the homepage?_**
#
# Within the further investigation of `What videos frequented the homepage the most?`, there was a possible pattern that could result in a video being posted to the homepage multiple times a day: views must grow larger than 500,000 within the first 24-48 hours of being posted. While it may be difficult to prove that conclusion, we can check if there is a minimum view count needed to be posted to the homepage (the minimum number of views implying that a video was only recently posted and had not previously been on the homepage.)
#
# Unfortunately, we can confirm that you can in fact have 0 views and still get featured on the homepage.

# %%
df_min_index = df.groupby('videoId')['views'].idxmin()
z=df.loc[df_min_index]
z=z[['title','views']].reset_index(drop=True)
z.rename(columns={'views':'min_views'},inplace=True)
z.sort_values(by='min_views',ascending=True).head()
# Out:
#                                                  title  min_views
# 562                      What is the Green Jedi Order?          0
# 626  Severance Real Filming Locations! #severance #...          0
# 623  before and after, Kiln load #NowWhatPotteryWor...          0
# 796          Fix Your Pesky Back Foot  Disc Golf Throw          0
# 799   This Welder is a Great Value #welder #arccaptain          0

# %% [markdown]
# That, along with the rather varied view count of when the most popular videos (most featured  & most viewed) first begin to be featured on the homepage, further support the conclusion that there are many other things to consider when determining what videos to feature on the homepage. Clearly, we need more information than what can be inferred by the provided data.

# %%
u=pd.merge(p['MOST FEATURED - title'],z,left_on='MOST FEATURED - title',right_on='title').drop(['title'],axis=1).reset_index()
v=pd.merge(j['MOST VIEWED - title'],z,left_on='MOST VIEWED - title',right_on='title').drop(['title'],axis=1).reset_index()
u.merge(v,on='index').drop(['index'],axis=1)
# Out:
#                                 MOST FEATURED - title  min_views_x  \
# 0                            LEGO BUILDS for a DOG...       844154
# 1              Tattoo - Tito Double P (Video Oficial)      1609151
# 2                             I'M HIGH SCHOOL MUSICAL      1828467
# 3                      Doechii - Anxiety (Visualizer)       792669
# 4   Bhad Bhabie -  OG CRASHOUT (Official Music Video)      2299259
# 5   Ariana Grande and Cynthia Erivo 'Wicked' Perfo...      1757257
# 6   Forging a Knife & Survival Camping Alone in th...       940711
# 7   Lilo & Stitch | Official Trailer | In Theaters...      5926520
# 8               There's Something LIVING in our Attic      3514550
# 9   Lil Baby, Young Thug, Future - Dum, Dumb, and ...      1093266
# 10                      My First Time Playing R.E.P.O      1380949
# 11              SIDEMEN AMONG US BUT EVERYTHING IS 3D      2911834
# 12          TIOS FOR A DAY W/ ADAM & LOUIE *FUNNY AF*       292917
# 13                                 AMP MMA BASKETBALL      1109932
# 14  YAILIN LA MAS VIRAL x DJ ADONI - Yo No Olvido ...       814790
# 15                   Can You Fool A Self Driving Car?      7805126
# 16              JENNIE - like JENNIE (Official Video)      6610705
# 17  Selena Gomez, benny blanco - Sunset Blvd (Offi...       985650
# 18                       Technology isn't fun anymore      1327891
#
#                                   MOST VIEWED - title  min_views_y
# 0              I Spent 100 Hours Inside The Pyramids!    147378599
# 1   Kendrick Lamar's Apple Music Super Bowl Halfti...     91940033
# 2          I Survived The 5 Deadliest Places On Earth     33698346
# 3               JENNIE - like JENNIE (Official Video)      6610705
# 4                   Cazzu - CON OTRA (Official Video)      3186526
# 5   Good Bad Ugly Tamil Teaser | Ajith Kumar | Tri...     32276743
# 6                LE SSERAFIM (르세라핌) 'HOT' OFFICIAL MV      8431871
# 7    The Last of Us Season 2 | Official Trailer | Max      7454824
# 8     Final Destination Bloodlines | Official Trailer      7788839
# 9                                FAILED LEGO ITEMS...     23081650
# 10          JENNIE, Doechii - ExtraL (Official Video)     21629819
# 11                  A Minecraft Movie | Final Trailer     13481802
# 12             Tattoo - Tito Double P (Video Oficial)      1609151
# 13  G-DRAGON - TOO BAD (feat. Anderson .Paak) (Off...     18817591
# 14                   Can You Fool A Self Driving Car?      7805126
# 15       SIDEMEN CHARITY MATCH 2025 [OFFICIAL STREAM]     16306337
# 16                     Doechii - Anxiety (Visualizer)       792669
# 17  The Paradise Glimpse : RAW STATEMENT - Telugu ...     18166710
# 18  LISA - FUTW (Vixi Solo Version) (Official Musi...      9082992

# %% [markdown]
# ##### <span style="color: blue;"> _What criteria keeps a video on the homepage? What causes a video's tenure on the homepage to end?_</span>

# %% [markdown]
# It is unlikely that view count is used to determine a video's placement on the homepage based on previous analysis. But from earlier work that determined that there are videos that have been on the homepage multiple times during March 2025 (`Does each day have different videos?`), maybe it is used to determine how long (`What videos frequented the homepage the most?`) a video continues to be on the homepage.
#
# To do this, I look at the percent change in views for days on the homepage. I hypothesize that when the view growth (while on the homepage) starts to plateau, a video gets pulled from the homepage. This, begs the question, what is that plateau?

# %%
def percent_change(df,group,target,func,new_name):
    o= df.groupby(group)[target].transform(func)
    o=o.fillna(0)
    df[new_name]= o
    return df

func = lambda x: (x-x.shift(1))/x.shift(1)*100.0
df_change = percent_change(df,'videoId','views',func,'percent_change')
x=df_change[['Date','title','percent_change']].drop_duplicates(subset=['Date','title'])
p=["Tattoo - Tito Double P (Video Oficial)","A Minecraft Movie | Final Trailer","JENNIE - like JENNIE (Official Video)","I'M HIGH SCHOOL MUSICAL","Doechii - Anxiety (Visualizer)","Final Destination Bloodlines | Official Trailer","G-DRAGON - TOO BAD (feat. Anderson .Paak) (Official Video)","SIDEMEN CHARITY MATCH 2025 [OFFICIAL STREAM]","AMP MMA BASKETBALL","Can You Fool A Self Driving Car?","Technology isn't fun anymore","I'M HIGH SCHOOL MUSICAL","AMP MMA BASKETBALL","LISA - FUTW (Vixi Solo Version) (Official Music Video)","I Survived The 5 Deadliest Places On Earth","Bill Murray Doesn’t Flinch While Eating Spicy Wings | Hot Ones"]
x=x[x['title'].isin(p)]
x
# Out:
#            Date                                              title  \
# 2    2025-03-01                       Technology isn't fun anymore
# 8    2025-03-01                  A Minecraft Movie | Final Trailer
# 9    2025-03-01  LISA - FUTW (Vixi Solo Version) (Official Musi...
# 16   2025-03-01             Tattoo - Tito Double P (Video Oficial)
# 69   2025-03-01  G-DRAGON - TOO BAD (feat. Anderson .Paak) (Off...
# ...         ...                                                ...
# 2802 2025-03-28                   Can You Fool A Self Driving Car?
# 2877 2025-03-29    Final Destination Bloodlines | Official Trailer
# 2914 2025-03-29                   Can You Fool A Self Driving Car?
# 2974 2025-03-30    Final Destination Bloodlines | Official Trailer
# 3075 2025-03-31    Final Destination Bloodlines | Official Trailer
#
#       percent_change
# 2           0.000000
# 8           0.000000
# 9           0.000000
# 16          0.000000
# 69          0.000000
# ...              ...
# 2802        0.687650
# 2877       21.468457
# 2914        0.829374
# 2974       16.769388
# 3075       10.137522
#
# [141 rows x 3 columns]

# %% [markdown]
# As quite a few of the videos in this dataset are only featured once and will not have any significant change in view count during their tenure, I focused my visualization on a sample of the videos on the top 20 most featured and top 20 most viewed lists.
#
# Through this, we find that some videos like _I Survived the Five Deadliest Places on Earth_ get pulled from the homepage while in the middle of viewership growth and others like the _Final Destination: Bloodline_ trailer seem to continue their tenure on the homepage into April 2025 (but look like they may follow the same pattern of rest of the videos), most of the videos percent change in viewership seem to follow a [Weibull Distribution](https://byjus.com/maths/weibull-distribution/) where viewership growth hits a peak within the first couple days of being on the homepage but eventually growth slows and plateaus to almost 0, marking the end of its tenure on the homepage.
#
# Unfortunately, this Weibull density may also be the result of viewership growth after a video gets published as this is common behavior to see of any content viewership performance. So, while this is a promising start to what affects a video's tenure on the homepage, we definitely need more information about all YouTube videos (featured & not featured) and other engagement metrics before concluding anything.

# %%
fig, ax = plt.subplots(figsize=(15, 8))
x=x.groupby('title')
# Plot each group as a separate line
palette=sns.color_palette("cubehelix", as_cmap=True)
for key, group in x:
    ax.plot(group['Date'], group['percent_change'], label=key)

# Set axis labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Percent Change')
ax.set_title('Percent Change in Views of Sample Over March 2025')

# Add a legend
ax.legend()

# Display the grid
ax.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### **Conclusion**

# %% [markdown]
# Through this analysis, I was able to look into the who and what of videos being featured on the YouTube homepage in March 2025. We found that a majority of videos being featured come from verified channels and that viewership engagement is unlikely to have any significant influence over being featured on the homepage. However, there is some evidence that we should continue looking into other engagement metrics to see if any sort of engagement metric influences a video's tenure on the homepage or if there is more to the story of how to get featured on the homepage as suggested by YouTube's favorable treatment of verified creators.
#
# While I was hoping the results would not be quite so inconclusive, it is very clear that the data chosen provides a very limited view of the videos deemed to be 'trending' and featured on the homepage, both in range of time and in metrics provided. There are still many measurable factors that we do not have access to that could provide more thorough answers to the questions we have posed. So as of now, what YouTube actually means when they call a video 'trending' is inconclusive.
